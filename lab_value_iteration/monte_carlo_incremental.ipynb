# %%
import helperff
import misc

# %%
env_b_greedy_small = helperff.make_env(is_slippery=False, map_size=5, proba_frozen=0.85, seed=69, max_steps=100)
V, N, returns, lengths = helperff.run_mc_experiment(
    env_b_greedy_small,
    episodes=1000,
    alpha=0.1,
    gamma=0.9,
    epsilon=0.9,
    epsilon_decay=0.99,
    first_visit=True,
    greedy=True,
    max_steps=100,
)
helperff.plot_experiment_results(env_b_greedy_small, V, N, returns, lengths, gamma=0.9)
# Out:
# Episode 100/1000 — letzte Return: -10.010, Länge: 2 — avg(last100) return: -3.220, len: 11.31
# Episode 200/1000 — letzte Return: -10.030, Länge: 4 — avg(last100) return: 4.987, len: 8.68
# Episode 300/1000 — letzte Return: 9.910, Länge: 10 — avg(last100) return: 8.189, len: 9.23
# Episode 400/1000 — letzte Return: 9.930, Länge: 8 — avg(last100) return: 9.440, len: 8.11
# Episode 500/1000 — letzte Return: 9.930, Länge: 8 — avg(last100) return: 9.889, len: 8.10
# Episode 600/1000 — letzte Return: 9.930, Länge: 8 — avg(last100) return: 9.530, len: 8.02
# Episode 700/1000 — letzte Return: 9.930, Länge: 8 — avg(last100) return: 9.930, len: 8.00
# Episode 800/1000 — letzte Return: 9.930, Länge: 8 — avg(last100) return: 9.930, len: 8.00
# Episode 900/1000 — letzte Return: 9.930, Länge: 8 — avg(last100) return: 9.930, len: 8.00
# Episode 1000/1000 — letzte Return: 9.930, Länge: 8 — avg(last100) return: 9.930, len: 8.00

# %%
env_b_greedy_big = helperff.make_env(is_slippery=False, map_size=11, proba_frozen=0.85, seed=69, max_steps=300)
V, N, returns, lengths = helperff.run_mc_experiment(
    env_b_greedy_big,
    episodes=30000,
    alpha=0.1,
    gamma=0.9,
    epsilon=1.0,
    epsilon_decay=0.9995,
    first_visit=True,
    greedy=True,
    max_steps=300,
)
helperff.plot_experiment_results(env_b_greedy_big, V, N, returns, lengths, gamma=0.9)
# Out:
# Episode 100/30000 — letzte Return: -10.040, Länge: 5 — avg(last100) return: -15.359, len: 30.00
# Episode 200/30000 — letzte Return: -22.240, Länge: 37 — avg(last100) return: -15.694, len: 29.85
# Episode 300/30000 — letzte Return: -19.820, Länge: 92 — avg(last100) return: -16.731, len: 43.51
# Episode 400/30000 — letzte Return: -13.280, Länge: 32 — avg(last100) return: -16.620, len: 48.37
# Episode 500/30000 — letzte Return: -25.730, Länge: 208 — avg(last100) return: -17.435, len: 56.06
# Episode 600/30000 — letzte Return: -15.340, Länge: 40 — avg(last100) return: -20.006, len: 73.93
# Episode 700/30000 — letzte Return: -21.860, Länge: 98 — avg(last100) return: -18.465, len: 70.27
# Episode 800/30000 — letzte Return: -11.040, Länge: 6 — avg(last100) return: -19.762, len: 93.10
# Episode 900/30000 — letzte Return: -20.690, Länge: 80 — avg(last100) return: -21.426, len: 96.23
# Episode 1000/30000 — letzte Return: -28.740, Länge: 300 — avg(last100) return: -21.181, len: 116.30
# Episode 1100/30000 — letzte Return: -45.570, Länge: 300 — avg(last100) return: -20.083, len: 122.05
# Episode 1200/30000 — letzte Return: -11.100, Länge: 12 — avg(last100) return: -22.464, len: 143.14
# Episode 1300/30000 — letzte Return: -13.260, Länge: 30 — avg(last100) return: -21.017, len: 136.52
# Episode 1400/30000 — letzte Return: -38.640, Länge: 300 — avg(last100) return: -21.946, len: 142.66
# Episode 1500/30000 — letzte Return: -48.540, Länge: 300 — avg(last100) return: -21.574, len: 169.74
# Episode 1600/30000 — letzte Return: -13.240, Länge: 28 — avg(last100) return: -14.409, len: 124.28
# Episode 1700/30000 — letzte Return: 9.650, Länge: 36 — avg(last100) return: -20.326, len: 164.14
# Episode 1800/30000 — letzte Return: 8.490, Länge: 53 — avg(last100) return: -13.305, len: 134.42
# Episode 1900/30000 — letzte Return: 2.350, Länge: 73 — avg(last100) return: -22.228, len: 227.04
# Episode 2000/30000 — letzte Return: 9.650, Länge: 36 — avg(last100) return: -16.570, len: 187.55
# Episode 2100/30000 — letzte Return: 8.090, Länge: 93 — avg(last100) return: -5.617, len: 118.63
# Episode 2200/30000 — letzte Return: -11.640, Länge: 66 — avg(last100) return: -6.696, len: 138.27
# Episode 2300/30000 — letzte Return: 8.370, Länge: 65 — avg(last100) return: -11.958, len: 167.49
# Episode 2400/30000 — letzte Return: -10.170, Länge: 18 — avg(last100) return: -9.625, len: 166.42
# Episode 2500/30000 — letzte Return: 2.790, Länge: 128 — avg(last100) return: 0.016, len: 73.64
# Episode 2600/30000 — letzte Return: 9.670, Länge: 34 — avg(last100) return: -1.440, len: 106.70
# Episode 2700/30000 — letzte Return: 9.790, Länge: 22 — avg(last100) return: 3.255, len: 45.45
# Episode 2800/30000 — letzte Return: 9.690, Länge: 32 — avg(last100) return: 1.553, len: 97.80
# Episode 2900/30000 — letzte Return: -12.220, Länge: 124 — avg(last100) return: 1.483, len: 81.59
# Episode 3000/30000 — letzte Return: -3.000, Länge: 300 — avg(last100) return: -4.138, len: 145.94
# Episode 3100/30000 — letzte Return: 9.790, Länge: 22 — avg(last100) return: 5.770, len: 64.01
# Episode 3200/30000 — letzte Return: 9.710, Länge: 30 — avg(last100) return: 7.591, len: 35.44
# Episode 3300/30000 — letzte Return: 8.770, Länge: 25 — avg(last100) return: 6.971, len: 38.49
# Episode 3400/30000 — letzte Return: -1.070, Länge: 217 — avg(last100) return: 3.803, len: 69.47
# Episode 3500/30000 — letzte Return: 8.790, Länge: 23 — avg(last100) return: 7.064, len: 49.84
# Episode 3600/30000 — letzte Return: 4.870, Länge: 118 — avg(last100) return: 4.689, len: 76.18
# Episode 3700/30000 — letzte Return: 9.390, Länge: 62 — avg(last100) return: 7.102, len: 41.51
# Episode 3800/30000 — letzte Return: 9.790, Länge: 22 — avg(last100) return: 8.407, len: 26.67
# Episode 3900/30000 — letzte Return: 9.750, Länge: 26 — avg(last100) return: 5.403, len: 60.34
# Episode 4000/30000 — letzte Return: 8.810, Länge: 21 — avg(last100) return: 6.091, len: 43.08
# Episode 4100/30000 — letzte Return: 8.810, Länge: 21 — avg(last100) return: 9.361, len: 23.32
# Episode 4200/30000 — letzte Return: 8.790, Länge: 23 — avg(last100) return: 8.780, len: 25.37
# Episode 4300/30000 — letzte Return: 6.410, Länge: 63 — avg(last100) return: 5.289, len: 61.05
# Episode 4400/30000 — letzte Return: 9.750, Länge: 26 — avg(last100) return: 3.967, len: 87.10
# Episode 4500/30000 — letzte Return: 8.810, Länge: 21 — avg(last100) return: 9.196, len: 22.59
# Episode 4600/30000 — letzte Return: 8.410, Länge: 61 — avg(last100) return: 8.841, len: 29.19
# Episode 4700/30000 — letzte Return: 9.790, Länge: 22 — avg(last100) return: 7.299, len: 43.45
# Episode 4800/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 8.803, len: 21.90
# Episode 4900/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.204, len: 21.75
# Episode 5000/30000 — letzte Return: 8.810, Länge: 21 — avg(last100) return: 9.204, len: 21.79
# Episode 5100/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 8.326, len: 39.60
# Episode 5200/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 8.859, len: 22.27
# Episode 5300/30000 — letzte Return: -10.180, Länge: 19 — avg(last100) return: 6.235, len: 70.99
# Episode 5400/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 8.734, len: 32.73
# Episode 5500/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.477, len: 21.41
# Episode 5600/30000 — letzte Return: 3.310, Länge: 274 — avg(last100) return: 7.929, len: 43.31
# Episode 5700/30000 — letzte Return: 9.770, Länge: 24 — avg(last100) return: 9.218, len: 22.32
# Episode 5800/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.298, len: 21.34
# Episode 5900/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.301, len: 20.96
# Episode 6000/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.490, len: 21.08
# Episode 6100/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 8.001, len: 41.29
# Episode 6200/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.152, len: 20.88
# Episode 6300/30000 — letzte Return: 9.770, Länge: 24 — avg(last100) return: 9.700, len: 21.14
# Episode 6400/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.560, len: 21.05
# Episode 6500/30000 — letzte Return: 9.790, Länge: 22 — avg(last100) return: 9.124, len: 20.71
# Episode 6600/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.594, len: 20.65
# Episode 6700/30000 — letzte Return: -5.970, Länge: 300 — avg(last100) return: 8.298, len: 36.30
# Episode 6800/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 7.580, len: 62.30
# Episode 6900/30000 — letzte Return: 8.810, Länge: 21 — avg(last100) return: 9.691, len: 20.97
# Episode 7000/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.544, len: 20.65
# Episode 7100/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.723, len: 20.74
# Episode 7200/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.744, len: 20.66
# Episode 7300/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.693, len: 20.77
# Episode 7400/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.524, len: 20.65
# Episode 7500/30000 — letzte Return: 9.770, Länge: 24 — avg(last100) return: 9.773, len: 20.77
# Episode 7600/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.775, len: 20.57
# Episode 7700/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.765, len: 20.56
# Episode 7800/30000 — letzte Return: 9.790, Länge: 22 — avg(last100) return: 9.794, len: 20.65
# Episode 7900/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.367, len: 20.34
# Episode 8000/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.378, len: 20.27
# Episode 8100/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.377, len: 20.30
# Episode 8200/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.587, len: 20.31
# Episode 8300/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.188, len: 20.20
# Episode 8400/30000 — letzte Return: 9.790, Länge: 22 — avg(last100) return: 9.786, len: 20.42
# Episode 8500/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.778, len: 20.27
# Episode 8600/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.399, len: 20.07
# Episode 8700/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.798, len: 20.21
# Episode 8800/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.807, len: 20.28
# Episode 8900/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.587, len: 20.33
# Episode 9000/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.778, len: 20.21
# Episode 9100/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.808, len: 20.24
# Episode 9200/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.778, len: 20.19
# Episode 9300/30000 — letzte Return: 9.790, Länge: 22 — avg(last100) return: 9.799, len: 20.15
# Episode 9400/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.789, len: 20.16
# Episode 9500/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.768, len: 20.22
# Episode 9600/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.788, len: 20.18
# Episode 9700/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.799, len: 20.15
# Episode 9800/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.600, len: 20.02
# Episode 9900/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.610, len: 20.01
# Episode 10000/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.599, len: 20.08
# Episode 10100/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.601, len: 19.96
# Episode 10200/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.799, len: 20.11
# Episode 10300/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.799, len: 20.13
# Episode 10400/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.600, len: 20.02
# Episode 10500/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.609, len: 20.05
# Episode 10600/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.809, len: 20.08
# Episode 10700/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.610, len: 19.99
# Episode 10800/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.809, len: 20.08
# Episode 10900/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.800, len: 20.05
# Episode 11000/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.610, len: 20.01
# Episode 11100/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.800, len: 20.05
# Episode 11200/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.799, len: 20.15
# Episode 11300/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.799, len: 20.07
# Episode 11400/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.809, len: 20.14
# Episode 11500/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.611, len: 19.93
# Episode 11600/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.799, len: 20.11
# Episode 11700/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.610, len: 19.97
# Episode 11800/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.809, len: 20.06
# Episode 11900/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.02
# Episode 12000/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.799, len: 20.07
# Episode 12100/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.610, len: 19.97
# Episode 12200/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.04
# Episode 12300/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.809, len: 20.14
# Episode 12400/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.04
# Episode 12500/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.809, len: 20.06
# Episode 12600/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.800, len: 20.05
# Episode 12700/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.809, len: 20.08
# Episode 12800/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.04
# Episode 12900/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.02
# Episode 13000/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.800, len: 20.05
# Episode 13100/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 13200/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.02
# Episode 13300/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 13400/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.04
# Episode 13500/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.04
# Episode 13600/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.04
# Episode 13700/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.02
# Episode 13800/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.02
# Episode 13900/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.800, len: 20.03
# Episode 14000/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 14100/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 14200/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.02
# Episode 14300/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.02
# Episode 14400/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.04
# Episode 14500/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.04
# Episode 14600/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.02
# Episode 14700/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 14800/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 14900/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.04
# Episode 15000/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 15100/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 15200/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 15300/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.800, len: 20.01
# Episode 15400/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 15500/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 15600/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.02
# Episode 15700/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 15800/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 15900/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 16000/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 16100/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 16200/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 16300/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 16400/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 16500/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.02
# Episode 16600/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 16700/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 16800/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 16900/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.02
# Episode 17000/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 17100/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 17200/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 17300/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 17400/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.02
# Episode 17500/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 17600/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 17700/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 17800/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 17900/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 18000/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.02
# Episode 18100/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 18200/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 18300/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 18400/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 18500/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 18600/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 18700/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 18800/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 18900/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 19000/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.02
# Episode 19100/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 19200/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 19300/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 19400/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 19500/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 19600/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 19700/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.02
# Episode 19800/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 19900/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 20000/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 20100/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 20200/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 20300/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 20400/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 20500/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 20600/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 20700/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 20800/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 20900/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 21000/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 21100/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 21200/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 21300/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.02
# Episode 21400/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 21500/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 21600/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 21700/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 21800/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 21900/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 22000/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 22100/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 22200/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 22300/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 22400/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 22500/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 22600/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 22700/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 22800/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 22900/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 23000/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 23100/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 23200/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 23300/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 23400/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 23500/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 23600/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 23700/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 23800/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 23900/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 24000/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 24100/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 24200/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 24300/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 24400/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 24500/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 24600/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 24700/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.02
# Episode 24800/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 24900/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 25000/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 25100/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 25200/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 25300/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 25400/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 25500/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 25600/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 25700/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 25800/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 25900/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 26000/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 26100/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 26200/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 26300/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 26400/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 26500/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 26600/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 26700/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 26800/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 26900/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 27000/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 27100/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 27200/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 27300/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 27400/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 27500/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 27600/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 27700/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 27800/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 27900/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 28000/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 28100/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 28200/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 28300/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 28400/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 28500/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 28600/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 28700/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 28800/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 28900/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 29000/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 29100/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 29200/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 29300/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 29400/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 29500/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 29600/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 29700/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 29800/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 29900/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
# Episode 30000/30000 — letzte Return: 9.810, Länge: 20 — avg(last100) return: 9.810, len: 20.00
