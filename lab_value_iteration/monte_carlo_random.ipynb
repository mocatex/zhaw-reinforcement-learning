# %%
import helperf
import gymnasium as gym
from gymnasium.envs.toy_text.frozen_lake import generate_random_map
import numpy as np
import matplotlib.pyplot as plt
from collections import defaultdict

# %% [markdown]
# ### Gamma = 1.0

# %%
env1 = helperf.make_env(map_size=5, proba_frozen=0.85, seed=42)
V1, N1 = helperf.mc_first_visit_V(env1, episodes=10000000, gamma=1.0)
helperf.print_heat_map(env1, V1, N1)

# %% [markdown]
# ### Gamma = 0.7

# %%
env2 = helperf.make_env(map_size=5, proba_frozen=0.85, seed=42)
V2, N2 = helperf.mc_first_visit_V(env1, episodes=100000, gamma=0.7)
helperf.print_heat_map(env2, V2, N2)

# %% [markdown]
# ### Gamma = 0.2

# %%
env3 = helperf.make_env(map_size=5, proba_frozen=0.85, seed=42)
V3, N3 = helperf.mc_first_visit_V(env1, episodes=100000, gamma=0.2)
helperf.print_heat_map(env3, V3, N3)
