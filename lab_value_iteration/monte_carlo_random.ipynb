# %%
import helperff

# %%
env_a_random_small = helperff.make_env(is_slippery=False, map_size=5, proba_frozen=0.85, seed=42)
V_a, N_a, returns_a, lengths_a = helperff.run_mc_experiment(
    env_a_random_small,
    episodes=10000,
    alpha=0.1,
    gamma=0.9,
    first_visit=True,
    greedy=False,
    max_steps=100,
)
helperff.plot_experiment_results(env_a_random_small, V_a, N_a, returns_a, lengths_a, gamma=0.9)
# Out:
# Episode 100/10000 — letzte Return: -11.010, Länge: 3 — avg(last100) return: -11.361, len: 3.43
# Episode 200/10000 — letzte Return: -12.020, Länge: 5 — avg(last100) return: -11.188, len: 4.32
# Episode 300/10000 — letzte Return: -11.010, Länge: 3 — avg(last100) return: -11.445, len: 3.94
# Episode 400/10000 — letzte Return: -13.000, Länge: 4 — avg(last100) return: -11.210, len: 3.24
# Episode 500/10000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -10.920, len: 3.15
# Episode 600/10000 — letzte Return: -13.050, Länge: 9 — avg(last100) return: -11.459, len: 4.33
# Episode 700/10000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.113, len: 3.57
# Episode 800/10000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.571, len: 3.65
# Episode 900/10000 — letzte Return: -10.010, Länge: 2 — avg(last100) return: -11.672, len: 3.82
# Episode 1000/10000 — letzte Return: -10.010, Länge: 2 — avg(last100) return: -11.736, len: 4.36
# Episode 1100/10000 — letzte Return: -11.020, Länge: 4 — avg(last100) return: -11.105, len: 3.95
# Episode 1200/10000 — letzte Return: -10.120, Länge: 13 — avg(last100) return: -11.332, len: 3.50
# Episode 1300/10000 — letzte Return: -12.010, Länge: 4 — avg(last100) return: -11.429, len: 3.32
# Episode 1400/10000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.469, len: 4.51
# Episode 1500/10000 — letzte Return: -12.000, Länge: 3 — avg(last100) return: -11.532, len: 3.72
# Episode 1600/10000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.613, len: 3.87
# Episode 1700/10000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.494, len: 3.88
# Episode 1800/10000 — letzte Return: -11.000, Länge: 2 — avg(last100) return: -11.766, len: 4.32
# Episode 1900/10000 — letzte Return: -18.000, Länge: 9 — avg(last100) return: -11.057, len: 3.91
# Episode 2000/10000 — letzte Return: -10.020, Länge: 3 — avg(last100) return: -11.283, len: 3.78
# Episode 2100/10000 — letzte Return: -10.020, Länge: 3 — avg(last100) return: -11.511, len: 3.63
# Episode 2200/10000 — letzte Return: -10.010, Länge: 2 — avg(last100) return: -11.192, len: 3.38
# Episode 2300/10000 — letzte Return: -13.000, Länge: 4 — avg(last100) return: -11.353, len: 3.63
# Episode 2400/10000 — letzte Return: -13.060, Länge: 10 — avg(last100) return: -11.271, len: 3.41
# Episode 2500/10000 — letzte Return: -11.020, Länge: 4 — avg(last100) return: -11.645, len: 4.12
# Episode 2600/10000 — letzte Return: -11.020, Länge: 4 — avg(last100) return: -11.584, len: 3.99
# Episode 2700/10000 — letzte Return: -11.010, Länge: 3 — avg(last100) return: -11.061, len: 3.16
# Episode 2800/10000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.682, len: 3.90
# Episode 2900/10000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.622, len: 3.81
# Episode 3000/10000 — letzte Return: -12.000, Länge: 3 — avg(last100) return: -11.568, len: 4.30
# Episode 3100/10000 — letzte Return: -12.000, Länge: 3 — avg(last100) return: -11.473, len: 3.73
# Episode 3200/10000 — letzte Return: -13.040, Länge: 8 — avg(last100) return: -11.093, len: 3.62
# Episode 3300/10000 — letzte Return: -11.020, Länge: 4 — avg(last100) return: -11.593, len: 3.91
# Episode 3400/10000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.545, len: 4.04
# Episode 3500/10000 — letzte Return: -13.010, Länge: 5 — avg(last100) return: -11.349, len: 3.24
# Episode 3600/10000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.597, len: 4.25
# Episode 3700/10000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.065, len: 3.59
# Episode 3800/10000 — letzte Return: -11.000, Länge: 2 — avg(last100) return: -11.604, len: 4.00
# Episode 3900/10000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.520, len: 3.55
# Episode 4000/10000 — letzte Return: -10.020, Länge: 3 — avg(last100) return: -11.288, len: 4.29
# Episode 4100/10000 — letzte Return: -18.110, Länge: 20 — avg(last100) return: -11.195, len: 3.84
# Episode 4200/10000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.533, len: 3.82
# Episode 4300/10000 — letzte Return: -11.000, Länge: 2 — avg(last100) return: -11.704, len: 4.10
# Episode 4400/10000 — letzte Return: -10.010, Länge: 2 — avg(last100) return: -11.415, len: 3.92
# Episode 4500/10000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.262, len: 3.45
# Episode 4600/10000 — letzte Return: -12.020, Länge: 5 — avg(last100) return: -11.654, len: 4.04
# Episode 4700/10000 — letzte Return: 2.830, Länge: 25 — avg(last100) return: -11.267, len: 4.10
# Episode 4800/10000 — letzte Return: -10.040, Länge: 5 — avg(last100) return: -11.524, len: 3.88
# Episode 4900/10000 — letzte Return: -11.010, Länge: 3 — avg(last100) return: -11.667, len: 4.55
# Episode 5000/10000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.335, len: 3.82
# Episode 5100/10000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.861, len: 3.91
# Episode 5200/10000 — letzte Return: -18.020, Länge: 11 — avg(last100) return: -11.492, len: 3.71
# Episode 5300/10000 — letzte Return: -11.010, Länge: 3 — avg(last100) return: -11.356, len: 3.93
# Episode 5400/10000 — letzte Return: -10.020, Länge: 3 — avg(last100) return: -11.653, len: 3.95
# Episode 5500/10000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.343, len: 3.65
# Episode 5600/10000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.104, len: 3.73
# Episode 5700/10000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.594, len: 3.94
# Episode 5800/10000 — letzte Return: -12.020, Länge: 5 — avg(last100) return: -11.412, len: 3.63
# Episode 5900/10000 — letzte Return: -11.010, Länge: 3 — avg(last100) return: -11.077, len: 3.93
# Episode 6000/10000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.411, len: 3.53
# Episode 6100/10000 — letzte Return: -11.000, Länge: 2 — avg(last100) return: -11.404, len: 3.77
# Episode 6200/10000 — letzte Return: -12.010, Länge: 4 — avg(last100) return: -11.626, len: 4.25
# Episode 6300/10000 — letzte Return: -11.020, Länge: 4 — avg(last100) return: -11.382, len: 3.55
# Episode 6400/10000 — letzte Return: -12.010, Länge: 4 — avg(last100) return: -11.736, len: 4.33
# Episode 6500/10000 — letzte Return: -19.020, Länge: 12 — avg(last100) return: -11.620, len: 3.61
# Episode 6600/10000 — letzte Return: -13.000, Länge: 4 — avg(last100) return: -11.494, len: 3.88
# Episode 6700/10000 — letzte Return: -13.040, Länge: 8 — avg(last100) return: -11.611, len: 3.70
# Episode 6800/10000 — letzte Return: -11.000, Länge: 2 — avg(last100) return: -11.096, len: 3.90
# Episode 6900/10000 — letzte Return: -12.080, Länge: 11 — avg(last100) return: -11.420, len: 3.45
# Episode 7000/10000 — letzte Return: -10.030, Länge: 4 — avg(last100) return: -11.534, len: 3.91
# Episode 7100/10000 — letzte Return: -10.010, Länge: 2 — avg(last100) return: -11.509, len: 3.38
# Episode 7200/10000 — letzte Return: -13.000, Länge: 4 — avg(last100) return: -11.384, len: 4.01
# Episode 7300/10000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.432, len: 3.67
# Episode 7400/10000 — letzte Return: -12.000, Länge: 3 — avg(last100) return: -11.490, len: 3.50
# Episode 7500/10000 — letzte Return: -12.010, Länge: 4 — avg(last100) return: -11.279, len: 3.21
# Episode 7600/10000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.404, len: 3.75
# Episode 7700/10000 — letzte Return: -13.020, Länge: 6 — avg(last100) return: -11.291, len: 3.35
# Episode 7800/10000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.470, len: 3.50
# Episode 7900/10000 — letzte Return: -11.000, Länge: 2 — avg(last100) return: -11.462, len: 3.70
# Episode 8000/10000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.445, len: 3.93
# Episode 8100/10000 — letzte Return: -11.000, Länge: 2 — avg(last100) return: -10.998, len: 4.19
# Episode 8200/10000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.362, len: 3.52
# Episode 8300/10000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.831, len: 3.97
# Episode 8400/10000 — letzte Return: -15.000, Länge: 6 — avg(last100) return: -11.434, len: 3.85
# Episode 8500/10000 — letzte Return: -13.060, Länge: 10 — avg(last100) return: -11.268, len: 4.25
# Episode 8600/10000 — letzte Return: -14.000, Länge: 5 — avg(last100) return: -11.615, len: 4.07
# Episode 8700/10000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.266, len: 3.84
# Episode 8800/10000 — letzte Return: -13.020, Länge: 6 — avg(last100) return: -11.381, len: 3.49
# Episode 8900/10000 — letzte Return: -19.170, Länge: 27 — avg(last100) return: -11.293, len: 3.58
# Episode 9000/10000 — letzte Return: -11.000, Länge: 2 — avg(last100) return: -11.567, len: 4.25
# Episode 9100/10000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.473, len: 4.01
# Episode 9200/10000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.491, len: 3.54
# Episode 9300/10000 — letzte Return: -11.010, Länge: 3 — avg(last100) return: -11.635, len: 4.32
# Episode 9400/10000 — letzte Return: -13.010, Länge: 5 — avg(last100) return: -11.554, len: 3.93
# Episode 9500/10000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.632, len: 3.77
# Episode 9600/10000 — letzte Return: -12.000, Länge: 3 — avg(last100) return: -11.366, len: 3.99
# Episode 9700/10000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.543, len: 3.81
# Episode 9800/10000 — letzte Return: -13.090, Länge: 13 — avg(last100) return: -11.644, len: 4.05
# Episode 9900/10000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.373, len: 3.65
# Episode 10000/10000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.304, len: 3.69

# %%
env_a_random_big = helperff.make_env(is_slippery=False, map_size=11, proba_frozen=0.85, seed=42)
V_b, N_b, returns_b, lengths_b = helperff.run_mc_experiment(
    env_a_random_big,
    episodes=30000,
    alpha=0.1,
    gamma=0.9,
    first_visit=True,
    greedy=False,
    max_steps=200,
)
helperff.plot_experiment_results(env_a_random_big, V_b, N_b, returns_b, lengths_b, gamma=0.9)
# Out:
# Episode 100/30000 — letzte Return: -12.010, Länge: 4 — avg(last100) return: -11.162, len: 3.36
# Episode 200/30000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.374, len: 3.73
# Episode 300/30000 — letzte Return: -14.040, Länge: 9 — avg(last100) return: -11.844, len: 4.22
# Episode 400/30000 — letzte Return: -16.010, Länge: 8 — avg(last100) return: -11.719, len: 4.57
# Episode 500/30000 — letzte Return: -11.010, Länge: 3 — avg(last100) return: -11.615, len: 4.11
# Episode 600/30000 — letzte Return: -12.020, Länge: 5 — avg(last100) return: -11.695, len: 5.13
# Episode 700/30000 — letzte Return: -11.090, Länge: 11 — avg(last100) return: -11.594, len: 4.01
# Episode 800/30000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.649, len: 4.51
# Episode 900/30000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.566, len: 5.12
# Episode 1000/30000 — letzte Return: -11.010, Länge: 3 — avg(last100) return: -11.243, len: 3.57
# Episode 1100/30000 — letzte Return: -13.010, Länge: 5 — avg(last100) return: -11.585, len: 4.04
# Episode 1200/30000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.668, len: 4.48
# Episode 1300/30000 — letzte Return: -14.020, Länge: 7 — avg(last100) return: -11.703, len: 4.02
# Episode 1400/30000 — letzte Return: -14.000, Länge: 5 — avg(last100) return: -11.687, len: 4.37
# Episode 1500/30000 — letzte Return: -13.020, Länge: 6 — avg(last100) return: -11.217, len: 3.90
# Episode 1600/30000 — letzte Return: -14.020, Länge: 7 — avg(last100) return: -11.659, len: 4.51
# Episode 1700/30000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.394, len: 3.82
# Episode 1800/30000 — letzte Return: -12.030, Länge: 6 — avg(last100) return: -11.525, len: 4.04
# Episode 1900/30000 — letzte Return: -11.000, Länge: 2 — avg(last100) return: -11.254, len: 3.66
# Episode 2000/30000 — letzte Return: -13.000, Länge: 4 — avg(last100) return: -11.505, len: 3.98
# Episode 2100/30000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.479, len: 4.35
# Episode 2200/30000 — letzte Return: -11.000, Länge: 2 — avg(last100) return: -11.325, len: 3.84
# Episode 2300/30000 — letzte Return: -11.320, Länge: 34 — avg(last100) return: -11.164, len: 3.54
# Episode 2400/30000 — letzte Return: -12.000, Länge: 3 — avg(last100) return: -11.528, len: 4.29
# Episode 2500/30000 — letzte Return: -11.000, Länge: 2 — avg(last100) return: -11.719, len: 4.63
# Episode 2600/30000 — letzte Return: -18.020, Länge: 11 — avg(last100) return: -11.285, len: 3.76
# Episode 2700/30000 — letzte Return: -13.010, Länge: 5 — avg(last100) return: -11.511, len: 3.65
# Episode 2800/30000 — letzte Return: -10.010, Länge: 2 — avg(last100) return: -11.181, len: 3.28
# Episode 2900/30000 — letzte Return: -12.010, Länge: 4 — avg(last100) return: -11.357, len: 4.03
# Episode 3000/30000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.306, len: 3.84
# Episode 3100/30000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.343, len: 3.67
# Episode 3200/30000 — letzte Return: -15.000, Länge: 6 — avg(last100) return: -11.555, len: 4.07
# Episode 3300/30000 — letzte Return: -11.020, Länge: 4 — avg(last100) return: -11.176, len: 3.91
# Episode 3400/30000 — letzte Return: -11.260, Länge: 28 — avg(last100) return: -11.180, len: 4.13
# Episode 3500/30000 — letzte Return: -10.030, Länge: 4 — avg(last100) return: -11.405, len: 3.91
# Episode 3600/30000 — letzte Return: -10.010, Länge: 2 — avg(last100) return: -11.625, len: 4.13
# Episode 3700/30000 — letzte Return: -11.000, Länge: 2 — avg(last100) return: -11.463, len: 3.72
# Episode 3800/30000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.431, len: 3.53
# Episode 3900/30000 — letzte Return: -10.020, Länge: 3 — avg(last100) return: -11.335, len: 3.82
# Episode 4000/30000 — letzte Return: -14.030, Länge: 8 — avg(last100) return: -11.650, len: 4.64
# Episode 4100/30000 — letzte Return: -12.010, Länge: 4 — avg(last100) return: -11.498, len: 3.27
# Episode 4200/30000 — letzte Return: -14.020, Länge: 7 — avg(last100) return: -11.496, len: 4.09
# Episode 4300/30000 — letzte Return: -13.040, Länge: 8 — avg(last100) return: -11.869, len: 4.76
# Episode 4400/30000 — letzte Return: -12.000, Länge: 3 — avg(last100) return: -11.621, len: 3.73
# Episode 4500/30000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.391, len: 3.48
# Episode 4600/30000 — letzte Return: -10.010, Länge: 2 — avg(last100) return: -11.495, len: 3.94
# Episode 4700/30000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.197, len: 3.84
# Episode 4800/30000 — letzte Return: -14.000, Länge: 5 — avg(last100) return: -11.485, len: 3.93
# Episode 4900/30000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.109, len: 2.96
# Episode 5000/30000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.572, len: 4.74
# Episode 5100/30000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.543, len: 3.82
# Episode 5200/30000 — letzte Return: -10.340, Länge: 35 — avg(last100) return: -11.459, len: 4.36
# Episode 5300/30000 — letzte Return: -11.000, Länge: 2 — avg(last100) return: -11.557, len: 4.22
# Episode 5400/30000 — letzte Return: -12.010, Länge: 4 — avg(last100) return: -11.511, len: 4.64
# Episode 5500/30000 — letzte Return: -13.000, Länge: 4 — avg(last100) return: -11.602, len: 3.76
# Episode 5600/30000 — letzte Return: -11.000, Länge: 2 — avg(last100) return: -11.464, len: 3.87
# Episode 5700/30000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.614, len: 3.97
# Episode 5800/30000 — letzte Return: -11.040, Länge: 6 — avg(last100) return: -11.588, len: 4.42
# Episode 5900/30000 — letzte Return: -12.000, Länge: 3 — avg(last100) return: -11.382, len: 3.59
# Episode 6000/30000 — letzte Return: -11.030, Länge: 5 — avg(last100) return: -11.401, len: 3.45
# Episode 6100/30000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.738, len: 4.55
# Episode 6200/30000 — letzte Return: -10.020, Länge: 3 — avg(last100) return: -11.373, len: 3.68
# Episode 6300/30000 — letzte Return: -14.000, Länge: 5 — avg(last100) return: -11.822, len: 4.05
# Episode 6400/30000 — letzte Return: -11.060, Länge: 8 — avg(last100) return: -11.522, len: 3.74
# Episode 6500/30000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.692, len: 3.88
# Episode 6600/30000 — letzte Return: -12.000, Länge: 3 — avg(last100) return: -11.239, len: 3.16
# Episode 6700/30000 — letzte Return: -11.000, Länge: 2 — avg(last100) return: -11.677, len: 5.35
# Episode 6800/30000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.371, len: 3.42
# Episode 6900/30000 — letzte Return: -12.000, Länge: 3 — avg(last100) return: -11.181, len: 3.27
# Episode 7000/30000 — letzte Return: -10.020, Länge: 3 — avg(last100) return: -11.674, len: 4.11
# Episode 7100/30000 — letzte Return: -10.010, Länge: 2 — avg(last100) return: -11.322, len: 3.56
# Episode 7200/30000 — letzte Return: -12.000, Länge: 3 — avg(last100) return: -11.571, len: 3.69
# Episode 7300/30000 — letzte Return: -13.010, Länge: 5 — avg(last100) return: -11.512, len: 3.69
# Episode 7400/30000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.680, len: 3.71
# Episode 7500/30000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.698, len: 4.52
# Episode 7600/30000 — letzte Return: -10.010, Länge: 2 — avg(last100) return: -11.503, len: 4.83
# Episode 7700/30000 — letzte Return: -12.020, Länge: 5 — avg(last100) return: -11.263, len: 4.59
# Episode 7800/30000 — letzte Return: -11.000, Länge: 2 — avg(last100) return: -11.685, len: 4.18
# Episode 7900/30000 — letzte Return: -11.000, Länge: 2 — avg(last100) return: -11.576, len: 4.16
# Episode 8000/30000 — letzte Return: -11.010, Länge: 3 — avg(last100) return: -11.583, len: 4.85
# Episode 8100/30000 — letzte Return: -12.000, Länge: 3 — avg(last100) return: -11.759, len: 4.61
# Episode 8200/30000 — letzte Return: -19.000, Länge: 10 — avg(last100) return: -11.517, len: 4.16
# Episode 8300/30000 — letzte Return: -15.000, Länge: 6 — avg(last100) return: -11.469, len: 4.36
# Episode 8400/30000 — letzte Return: -10.020, Länge: 3 — avg(last100) return: -11.454, len: 3.85
# Episode 8500/30000 — letzte Return: -12.000, Länge: 3 — avg(last100) return: -11.536, len: 4.13
# Episode 8600/30000 — letzte Return: -10.040, Länge: 5 — avg(last100) return: -11.508, len: 4.32
# Episode 8700/30000 — letzte Return: -13.000, Länge: 4 — avg(last100) return: -11.489, len: 4.42
# Episode 8800/30000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.327, len: 3.98
# Episode 8900/30000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.215, len: 3.69
# Episode 9000/30000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.582, len: 3.75
# Episode 9100/30000 — letzte Return: -12.000, Länge: 3 — avg(last100) return: -11.250, len: 3.19
# Episode 9200/30000 — letzte Return: -12.010, Länge: 4 — avg(last100) return: -11.300, len: 4.24
# Episode 9300/30000 — letzte Return: -11.000, Länge: 2 — avg(last100) return: -11.657, len: 4.30
# Episode 9400/30000 — letzte Return: -12.010, Länge: 4 — avg(last100) return: -11.329, len: 4.19
# Episode 9500/30000 — letzte Return: -10.030, Länge: 4 — avg(last100) return: -11.502, len: 3.73
# Episode 9600/30000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.411, len: 3.47
# Episode 9700/30000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.704, len: 4.11
# Episode 9800/30000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.641, len: 4.72
# Episode 9900/30000 — letzte Return: -10.010, Länge: 2 — avg(last100) return: -11.170, len: 4.17
# Episode 10000/30000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.830, len: 4.86
# Episode 10100/30000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.183, len: 3.44
# Episode 10200/30000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.439, len: 4.34
# Episode 10300/30000 — letzte Return: -10.010, Länge: 2 — avg(last100) return: -11.606, len: 4.16
# Episode 10400/30000 — letzte Return: -10.070, Länge: 8 — avg(last100) return: -11.210, len: 4.18
# Episode 10500/30000 — letzte Return: -11.010, Länge: 3 — avg(last100) return: -11.807, len: 4.48
# Episode 10600/30000 — letzte Return: -12.030, Länge: 6 — avg(last100) return: -11.742, len: 3.94
# Episode 10700/30000 — letzte Return: -11.000, Länge: 2 — avg(last100) return: -11.703, len: 3.96
# Episode 10800/30000 — letzte Return: -11.000, Länge: 2 — avg(last100) return: -11.297, len: 3.93
# Episode 10900/30000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.276, len: 3.87
# Episode 11000/30000 — letzte Return: -12.020, Länge: 5 — avg(last100) return: -11.704, len: 4.07
# Episode 11100/30000 — letzte Return: -12.000, Länge: 3 — avg(last100) return: -11.576, len: 4.15
# Episode 11200/30000 — letzte Return: -10.020, Länge: 3 — avg(last100) return: -11.717, len: 4.36
# Episode 11300/30000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.191, len: 3.25
# Episode 11400/30000 — letzte Return: -10.010, Länge: 2 — avg(last100) return: -11.474, len: 3.85
# Episode 11500/30000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.223, len: 4.55
# Episode 11600/30000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.423, len: 3.68
# Episode 11700/30000 — letzte Return: -16.020, Länge: 9 — avg(last100) return: -11.414, len: 3.79
# Episode 11800/30000 — letzte Return: -12.000, Länge: 3 — avg(last100) return: -11.367, len: 3.10
# Episode 11900/30000 — letzte Return: -10.010, Länge: 2 — avg(last100) return: -11.337, len: 4.02
# Episode 12000/30000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.715, len: 4.16
# Episode 12100/30000 — letzte Return: -10.010, Länge: 2 — avg(last100) return: -11.482, len: 4.65
# Episode 12200/30000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.666, len: 4.26
# Episode 12300/30000 — letzte Return: -10.010, Länge: 2 — avg(last100) return: -11.456, len: 4.01
# Episode 12400/30000 — letzte Return: -10.010, Länge: 2 — avg(last100) return: -11.349, len: 4.21
# Episode 12500/30000 — letzte Return: -11.000, Länge: 2 — avg(last100) return: -11.183, len: 3.45
# Episode 12600/30000 — letzte Return: -11.000, Länge: 2 — avg(last100) return: -11.518, len: 5.42
# Episode 12700/30000 — letzte Return: -11.000, Länge: 2 — avg(last100) return: -11.845, len: 4.29
# Episode 12800/30000 — letzte Return: -11.000, Länge: 2 — avg(last100) return: -11.675, len: 4.11
# Episode 12900/30000 — letzte Return: -10.020, Länge: 3 — avg(last100) return: -11.412, len: 3.58
# Episode 13000/30000 — letzte Return: -11.010, Länge: 3 — avg(last100) return: -11.447, len: 4.11
# Episode 13100/30000 — letzte Return: -13.010, Länge: 5 — avg(last100) return: -11.663, len: 3.97
# Episode 13200/30000 — letzte Return: -11.000, Länge: 2 — avg(last100) return: -11.467, len: 4.13
# Episode 13300/30000 — letzte Return: -11.000, Länge: 2 — avg(last100) return: -11.467, len: 4.20
# Episode 13400/30000 — letzte Return: -13.200, Länge: 24 — avg(last100) return: -11.274, len: 3.69
# Episode 13500/30000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.551, len: 4.64
# Episode 13600/30000 — letzte Return: -11.040, Länge: 6 — avg(last100) return: -11.260, len: 4.26
# Episode 13700/30000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.688, len: 4.45
# Episode 13800/30000 — letzte Return: -11.030, Länge: 5 — avg(last100) return: -11.358, len: 4.19
# Episode 13900/30000 — letzte Return: -14.030, Länge: 8 — avg(last100) return: -11.840, len: 4.84
# Episode 14000/30000 — letzte Return: -11.000, Länge: 2 — avg(last100) return: -11.433, len: 3.73
# Episode 14100/30000 — letzte Return: -13.000, Länge: 4 — avg(last100) return: -11.334, len: 4.72
# Episode 14200/30000 — letzte Return: -11.020, Länge: 4 — avg(last100) return: -11.827, len: 4.49
# Episode 14300/30000 — letzte Return: -10.020, Länge: 3 — avg(last100) return: -11.230, len: 4.20
# Episode 14400/30000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.482, len: 3.69
# Episode 14500/30000 — letzte Return: -17.000, Länge: 8 — avg(last100) return: -11.940, len: 4.89
# Episode 14600/30000 — letzte Return: -11.000, Länge: 2 — avg(last100) return: -11.521, len: 3.57
# Episode 14700/30000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.838, len: 4.61
# Episode 14800/30000 — letzte Return: -12.010, Länge: 4 — avg(last100) return: -11.453, len: 3.73
# Episode 14900/30000 — letzte Return: -11.020, Länge: 4 — avg(last100) return: -11.385, len: 3.87
# Episode 15000/30000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.645, len: 4.12
# Episode 15100/30000 — letzte Return: -13.000, Länge: 4 — avg(last100) return: -11.447, len: 4.17
# Episode 15200/30000 — letzte Return: -11.100, Länge: 12 — avg(last100) return: -11.294, len: 3.70
# Episode 15300/30000 — letzte Return: -14.020, Länge: 7 — avg(last100) return: -12.002, len: 5.16
# Episode 15400/30000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.301, len: 3.42
# Episode 15500/30000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.490, len: 4.45
# Episode 15600/30000 — letzte Return: -11.010, Länge: 3 — avg(last100) return: -11.523, len: 3.86
# Episode 15700/30000 — letzte Return: -14.080, Länge: 13 — avg(last100) return: -11.543, len: 4.81
# Episode 15800/30000 — letzte Return: -11.000, Länge: 2 — avg(last100) return: -11.525, len: 4.02
# Episode 15900/30000 — letzte Return: -14.000, Länge: 5 — avg(last100) return: -11.706, len: 4.26
# Episode 16000/30000 — letzte Return: -14.010, Länge: 6 — avg(last100) return: -11.746, len: 4.33
# Episode 16100/30000 — letzte Return: -10.020, Länge: 3 — avg(last100) return: -11.721, len: 3.79
# Episode 16200/30000 — letzte Return: -12.000, Länge: 3 — avg(last100) return: -11.634, len: 3.99
# Episode 16300/30000 — letzte Return: -17.000, Länge: 8 — avg(last100) return: -11.831, len: 4.94
# Episode 16400/30000 — letzte Return: -11.000, Länge: 2 — avg(last100) return: -11.221, len: 3.35
# Episode 16500/30000 — letzte Return: -13.000, Länge: 4 — avg(last100) return: -11.491, len: 3.56
# Episode 16600/30000 — letzte Return: -11.000, Länge: 2 — avg(last100) return: -11.363, len: 3.61
# Episode 16700/30000 — letzte Return: -12.000, Länge: 3 — avg(last100) return: -11.598, len: 4.39
# Episode 16800/30000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.210, len: 4.15
# Episode 16900/30000 — letzte Return: -14.050, Länge: 10 — avg(last100) return: -11.473, len: 5.00
# Episode 17000/30000 — letzte Return: -11.000, Länge: 2 — avg(last100) return: -11.393, len: 3.72
# Episode 17100/30000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.270, len: 3.30
# Episode 17200/30000 — letzte Return: -11.020, Länge: 4 — avg(last100) return: -11.270, len: 3.23
# Episode 17300/30000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.192, len: 3.39
# Episode 17400/30000 — letzte Return: -13.200, Länge: 24 — avg(last100) return: -11.670, len: 4.62
# Episode 17500/30000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.321, len: 3.38
# Episode 17600/30000 — letzte Return: -10.020, Länge: 3 — avg(last100) return: -11.506, len: 4.11
# Episode 17700/30000 — letzte Return: -13.030, Länge: 7 — avg(last100) return: -11.642, len: 4.95
# Episode 17800/30000 — letzte Return: -11.020, Länge: 4 — avg(last100) return: -11.404, len: 4.77
# Episode 17900/30000 — letzte Return: -10.020, Länge: 3 — avg(last100) return: -11.242, len: 3.39
# Episode 18000/30000 — letzte Return: -10.010, Länge: 2 — avg(last100) return: -11.444, len: 3.88
# Episode 18100/30000 — letzte Return: -11.010, Länge: 3 — avg(last100) return: -11.686, len: 5.22
# Episode 18200/30000 — letzte Return: -13.000, Länge: 4 — avg(last100) return: -11.329, len: 3.25
# Episode 18300/30000 — letzte Return: -12.000, Länge: 3 — avg(last100) return: -11.524, len: 4.97
# Episode 18400/30000 — letzte Return: -12.030, Länge: 6 — avg(last100) return: -11.595, len: 4.10
# Episode 18500/30000 — letzte Return: -12.000, Länge: 3 — avg(last100) return: -11.322, len: 3.54
# Episode 18600/30000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.233, len: 3.57
# Episode 18700/30000 — letzte Return: -12.080, Länge: 11 — avg(last100) return: -11.516, len: 4.07
# Episode 18800/30000 — letzte Return: -12.020, Länge: 5 — avg(last100) return: -11.423, len: 3.71
# Episode 18900/30000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.624, len: 4.05
# Episode 19000/30000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.341, len: 3.42
# Episode 19100/30000 — letzte Return: -10.020, Länge: 3 — avg(last100) return: -11.530, len: 4.48
# Episode 19200/30000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.403, len: 3.69
# Episode 19300/30000 — letzte Return: -11.010, Länge: 3 — avg(last100) return: -11.315, len: 4.81
# Episode 19400/30000 — letzte Return: -13.010, Länge: 5 — avg(last100) return: -11.401, len: 3.47
# Episode 19500/30000 — letzte Return: -10.020, Länge: 3 — avg(last100) return: -11.342, len: 4.56
# Episode 19600/30000 — letzte Return: -11.000, Länge: 2 — avg(last100) return: -11.646, len: 4.26
# Episode 19700/30000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.158, len: 3.92
# Episode 19800/30000 — letzte Return: -12.010, Länge: 4 — avg(last100) return: -11.145, len: 3.66
# Episode 19900/30000 — letzte Return: -14.000, Länge: 5 — avg(last100) return: -11.575, len: 4.09
# Episode 20000/30000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.652, len: 3.83
# Episode 20100/30000 — letzte Return: -13.010, Länge: 5 — avg(last100) return: -11.422, len: 3.59
# Episode 20200/30000 — letzte Return: -10.010, Länge: 2 — avg(last100) return: -11.387, len: 4.02
# Episode 20300/30000 — letzte Return: -17.010, Länge: 9 — avg(last100) return: -11.450, len: 4.65
# Episode 20400/30000 — letzte Return: -11.000, Länge: 2 — avg(last100) return: -11.298, len: 3.13
# Episode 20500/30000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.411, len: 3.53
# Episode 20600/30000 — letzte Return: -13.010, Länge: 5 — avg(last100) return: -11.110, len: 3.08
# Episode 20700/30000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.418, len: 4.19
# Episode 20800/30000 — letzte Return: -14.000, Länge: 5 — avg(last100) return: -11.534, len: 3.95
# Episode 20900/30000 — letzte Return: -13.000, Länge: 4 — avg(last100) return: -11.287, len: 3.96
# Episode 21000/30000 — letzte Return: -12.000, Länge: 3 — avg(last100) return: -11.517, len: 4.17
# Episode 21100/30000 — letzte Return: -11.020, Länge: 4 — avg(last100) return: -11.506, len: 4.12
# Episode 21200/30000 — letzte Return: -10.010, Länge: 2 — avg(last100) return: -11.496, len: 5.08
# Episode 21300/30000 — letzte Return: -11.000, Länge: 2 — avg(last100) return: -11.480, len: 3.43
# Episode 21400/30000 — letzte Return: -11.020, Länge: 4 — avg(last100) return: -11.692, len: 4.86
# Episode 21500/30000 — letzte Return: -14.050, Länge: 10 — avg(last100) return: -11.594, len: 3.95
# Episode 21600/30000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.687, len: 4.33
# Episode 21700/30000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.598, len: 4.42
# Episode 21800/30000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.331, len: 3.42
# Episode 21900/30000 — letzte Return: -14.040, Länge: 9 — avg(last100) return: -11.396, len: 4.01
# Episode 22000/30000 — letzte Return: -11.000, Länge: 2 — avg(last100) return: -11.461, len: 3.54
# Episode 22100/30000 — letzte Return: -11.000, Länge: 2 — avg(last100) return: -11.577, len: 4.22
# Episode 22200/30000 — letzte Return: -13.000, Länge: 4 — avg(last100) return: -11.212, len: 3.43
# Episode 22300/30000 — letzte Return: -28.020, Länge: 21 — avg(last100) return: -11.530, len: 3.55
# Episode 22400/30000 — letzte Return: -10.010, Länge: 2 — avg(last100) return: -11.504, len: 3.88
# Episode 22500/30000 — letzte Return: -15.020, Länge: 8 — avg(last100) return: -11.361, len: 3.43
# Episode 22600/30000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.414, len: 3.79
# Episode 22700/30000 — letzte Return: -12.020, Länge: 5 — avg(last100) return: -11.478, len: 4.24
# Episode 22800/30000 — letzte Return: -13.040, Länge: 8 — avg(last100) return: -11.295, len: 3.80
# Episode 22900/30000 — letzte Return: -11.000, Länge: 2 — avg(last100) return: -11.313, len: 3.63
# Episode 23000/30000 — letzte Return: -12.010, Länge: 4 — avg(last100) return: -11.717, len: 4.42
# Episode 23100/30000 — letzte Return: -11.000, Länge: 2 — avg(last100) return: -11.391, len: 3.51
# Episode 23200/30000 — letzte Return: -13.200, Länge: 24 — avg(last100) return: -11.070, len: 4.10
# Episode 23300/30000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.331, len: 3.42
# Episode 23400/30000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.489, len: 4.42
# Episode 23500/30000 — letzte Return: -11.000, Länge: 2 — avg(last100) return: -11.311, len: 3.39
# Episode 23600/30000 — letzte Return: -11.020, Länge: 4 — avg(last100) return: -11.375, len: 3.91
# Episode 23700/30000 — letzte Return: -11.020, Länge: 4 — avg(last100) return: -11.747, len: 5.55
# Episode 23800/30000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.333, len: 4.64
# Episode 23900/30000 — letzte Return: -15.090, Länge: 15 — avg(last100) return: -11.436, len: 3.98
# Episode 24000/30000 — letzte Return: -10.030, Länge: 4 — avg(last100) return: -11.425, len: 3.89
# Episode 24100/30000 — letzte Return: -15.000, Länge: 6 — avg(last100) return: -11.307, len: 3.97
# Episode 24200/30000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.413, len: 3.75
# Episode 24300/30000 — letzte Return: -11.000, Länge: 2 — avg(last100) return: -11.850, len: 4.85
# Episode 24400/30000 — letzte Return: -17.000, Länge: 8 — avg(last100) return: -11.415, len: 3.95
# Episode 24500/30000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.427, len: 4.07
# Episode 24600/30000 — letzte Return: -12.020, Länge: 5 — avg(last100) return: -11.363, len: 3.68
# Episode 24700/30000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.504, len: 3.93
# Episode 24800/30000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.443, len: 3.69
# Episode 24900/30000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.665, len: 4.18
# Episode 25000/30000 — letzte Return: -11.060, Länge: 8 — avg(last100) return: -11.465, len: 3.99
# Episode 25100/30000 — letzte Return: -10.020, Länge: 3 — avg(last100) return: -11.554, len: 3.89
# Episode 25200/30000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.623, len: 4.85
# Episode 25300/30000 — letzte Return: -12.010, Länge: 4 — avg(last100) return: -11.717, len: 4.44
# Episode 25400/30000 — letzte Return: -11.030, Länge: 5 — avg(last100) return: -11.232, len: 3.38
# Episode 25500/30000 — letzte Return: -10.260, Länge: 27 — avg(last100) return: -11.485, len: 4.97
# Episode 25600/30000 — letzte Return: -11.020, Länge: 4 — avg(last100) return: -11.227, len: 3.95
# Episode 25700/30000 — letzte Return: -11.000, Länge: 2 — avg(last100) return: -11.244, len: 3.59
# Episode 25800/30000 — letzte Return: -11.010, Länge: 3 — avg(last100) return: -11.415, len: 4.93
# Episode 25900/30000 — letzte Return: -11.020, Länge: 4 — avg(last100) return: -11.262, len: 3.45
# Episode 26000/30000 — letzte Return: -11.000, Länge: 2 — avg(last100) return: -11.610, len: 4.58
# Episode 26100/30000 — letzte Return: -15.010, Länge: 7 — avg(last100) return: -11.427, len: 4.14
# Episode 26200/30000 — letzte Return: -12.000, Länge: 3 — avg(last100) return: -11.381, len: 3.51
# Episode 26300/30000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.398, len: 3.21
# Episode 26400/30000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.477, len: 4.37
# Episode 26500/30000 — letzte Return: -13.000, Länge: 4 — avg(last100) return: -11.446, len: 4.00
# Episode 26600/30000 — letzte Return: -11.020, Länge: 4 — avg(last100) return: -11.551, len: 3.69
# Episode 26700/30000 — letzte Return: -14.030, Länge: 8 — avg(last100) return: -11.659, len: 4.52
# Episode 26800/30000 — letzte Return: -19.020, Länge: 12 — avg(last100) return: -11.523, len: 3.84
# Episode 26900/30000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.616, len: 4.16
# Episode 27000/30000 — letzte Return: -12.010, Länge: 4 — avg(last100) return: -11.455, len: 5.05
# Episode 27100/30000 — letzte Return: -11.040, Länge: 6 — avg(last100) return: -11.700, len: 3.64
# Episode 27200/30000 — letzte Return: -12.020, Länge: 5 — avg(last100) return: -11.239, len: 5.12
# Episode 27300/30000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.365, len: 3.84
# Episode 27400/30000 — letzte Return: -12.020, Länge: 5 — avg(last100) return: -11.750, len: 4.68
# Episode 27500/30000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.640, len: 4.65
# Episode 27600/30000 — letzte Return: -11.030, Länge: 5 — avg(last100) return: -11.362, len: 3.53
# Episode 27700/30000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.613, len: 3.94
# Episode 27800/30000 — letzte Return: -12.040, Länge: 7 — avg(last100) return: -11.726, len: 4.32
# Episode 27900/30000 — letzte Return: -11.020, Länge: 4 — avg(last100) return: -11.535, len: 3.98
# Episode 28000/30000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.457, len: 4.12
# Episode 28100/30000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.546, len: 5.14
# Episode 28200/30000 — letzte Return: -11.000, Länge: 2 — avg(last100) return: -11.450, len: 4.48
# Episode 28300/30000 — letzte Return: -11.000, Länge: 2 — avg(last100) return: -11.588, len: 4.33
# Episode 28400/30000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.355, len: 4.79
# Episode 28500/30000 — letzte Return: -11.000, Länge: 2 — avg(last100) return: -11.389, len: 4.30
# Episode 28600/30000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.664, len: 4.07
# Episode 28700/30000 — letzte Return: -11.020, Länge: 4 — avg(last100) return: -11.335, len: 3.78
# Episode 28800/30000 — letzte Return: -14.020, Länge: 7 — avg(last100) return: -11.363, len: 3.70
# Episode 28900/30000 — letzte Return: -11.000, Länge: 2 — avg(last100) return: -11.447, len: 4.14
# Episode 29000/30000 — letzte Return: -12.010, Länge: 4 — avg(last100) return: -11.781, len: 3.88
# Episode 29100/30000 — letzte Return: -11.000, Länge: 2 — avg(last100) return: -11.717, len: 4.37
# Episode 29200/30000 — letzte Return: -14.040, Länge: 9 — avg(last100) return: -11.755, len: 5.28
# Episode 29300/30000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.563, len: 3.88
# Episode 29400/30000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.321, len: 5.43
# Episode 29500/30000 — letzte Return: -11.000, Länge: 2 — avg(last100) return: -11.862, len: 4.01
# Episode 29600/30000 — letzte Return: -10.060, Länge: 7 — avg(last100) return: -11.301, len: 3.36
# Episode 29700/30000 — letzte Return: -10.000, Länge: 1 — avg(last100) return: -11.507, len: 4.19
# Episode 29800/30000 — letzte Return: -10.010, Länge: 2 — avg(last100) return: -11.286, len: 3.83
# Episode 29900/30000 — letzte Return: -12.050, Länge: 8 — avg(last100) return: -11.554, len: 3.96
# Episode 30000/30000 — letzte Return: -11.010, Länge: 3 — avg(last100) return: -11.407, len: 4.12
